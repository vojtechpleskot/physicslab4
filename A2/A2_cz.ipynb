# %%
# TODO: Replace the string "Your Name" and "DD.MM.YYYY" with the appropriate values.

from header import header
_ = header(student = "Your Name", date = "DD.MM.YYYY", task_no = 2)

# %% [markdown]
# # Úvod
#
# Nejstarší a dosud nejběžnější metody, kterými lze měřit a srovnávat aktivity radioaktivních
# zářičů, jsou založeny na ionizačních účincích záření v plynech. Plyny se stávají vodivými,
# prochází-li jimi ionizační záření. Vnikne-li ionizující částice do prostoru mezi desky
# kondenzátoru, na němž je přiložené napětí, vytvoří podél své dráhy kladné a záporné ionty
# nebo volné elektrony, které jsou uváděny elektrickým polem do pohybu směrem
# k elektrodám, a mezi deskami kondenzátoru prochází ionizační proud. Ionizační proud závisí
# na intenzitě ionizačního záření, na energii ionizujících částic a na napětí mezi deskami
# kondenzátoru. Protože ionizační ztráty závisí na druhu ionizující částice a na její počáteční
# energii, lze popsané zařízení využít pro rozlišení druhu částic nebo pro rozlišení mezi
# energiemi identického druhu záření.
#
# ## Charakteristika plynového detektoru
#
# Závislost ionizačního proudu na napětí mezi elektrodami detektoru, tj. charakteristika ionizační komory, je
# důležitá pro výběr způsobu a podmínek provozu detektoru. V normálních případech při
# konstantní intenzitě ionizujícího záření vykazuje typickou závislost, kterou lze rozdělit do následujících
# oblastí:
#
# - `Oblast Ohmova zákona`. Není-li na elektrody detektoru přivedeno žádné napětí,
# neprochází komorou elektrický proud. Ionty a elektrony vytvořené zářením úplně
# rekombinují, případně difundují mimo aktivní oblast detektoru. Připojení malého
# napětí vede k rozdělení volných nosičů náboje opačných znamének. Rychlost jejich
# pohybu k odpovídajícím elektrodám je přímo úměrná intenzitě elektrického pole.
# Ionizační proud proto roste přímo úměrně s napětím.
#
# - Při vzrůstajícím napětí jsou nosiče náboje rychleji odsávány k elektrodám, klesá
# množství iontů v aktivní oblasti a tím klesá i šance pro jejich rekombinaci. Úměrnost
# proudu s napětím přestává platit. Stoupání proudu s napětím se zvolňuje.
#
# - `Oblast nasyceného proudu` je charakterizovaná stálou hodnotou ionizačního proudu,
# nezávislou na napětí. Při dostatečně vysokém napětí je rychlost rekombinace potlačena
# na zanedbatelnou úroveň a veškerý volný náboj, vytvořený ionizací přispívá
# k ionizačnímu proudu. Další zvyšování napětí již nemůže vést ke zvyšování proudu,
# jelikož veškerý volný náboj je již sebrán a rychlost tvorby náboje je konstantní. Tato
# oblast je typická pro provoz ionizačních komor.
#
# - `Oblast plynového/lavinového zesílení`. Ionty a elektrony na své cestě k elektrodám
# procházejí mnoha srážkami s neutrálními molekulami/atomy plynové náplně
# detektoru. Při dostatečně vysoké intenzitě elektrického pole ($10^6~\mathrm{V/m}$ pro typické
# plyny) získají elektrony mezi srážkami energii vyšší než je ionizační energie.
# V následné srážce pak mohou vytvořit nový iontový pár. Sekundární iontový pár je
# pak také urychlen elektrickým polem a vytváří další iontové páry. Tímto způsobem
# vzniká tzv. lavinové zesílení, kdy každý elektron uvolněný v primární ionizaci
# zářením generuje určité množství sekundárních volných elektronů přispívajících
# k elektrickému proudu.
#
# - `Oblast proporcionality`. V této oblasti je plynové zesílení nezávislé na primární
# ionizaci. Ionizační proud je tedy úměrný počtu iontových párů vzniklých přímým
# působením záření, tedy i celkové ztrátě energie záření v komoře.
#
# - `Oblast omezené proporcionality`. Při dalším zvyšování napětí se začne projevovat,
# že zatímco volné elektrony dospějí k anodě velice rychle, kladné ionty se během
# stejné doby téměř nepohnou z místa jejich vzniku a pomalu driftují ke katodě. Je-li
# koncentrace kladných iontů v objemu detektoru dostatečně velká, představují
# prostorový náboj, který významně redukuje intenzitu elektrického pole. Tím je
# zeslabeno další plynové zesílení a dochází k porušení úměrnosti mezi signálem a
# primární ionizací. I nadále platí, že větší deponované energii v detektoru odpovídá
# větší signál, nejde však již o přímou úměrnost.
#
# - `Geigerova-Müllerova oblast`. Při dostatečně vysokém napětí rozvoj laviny probíhá jen
# do okamžiku, než vznikající kladný prostorový náboj redukuje intenzitu
# elektrického pole na úroveň, kdy již nemůže docházet k plynovému zesílení.
# Tehdy všechny impulsy detektoru mají stejnou amplitudu, nezávislou na druhu a
# energii záření.
#
# Typická charakteristika plynového detektoru je zobrazena na obr. 1.
#
# !['Charakteristika plynového detektoru'](figures/VA_cs.png)
#
# Obr. 1: Charakteristika plynového detektoru
#
# ## Typy plynových detektorů
#
# Na ionizaci je založena celá řada přístrojů určených k měření jaderného záření. Jednotlivé
# oblasti charakteristiky popsaného zařízení využívají různé typy plynových počítačů. Oblast
# Ohmova zákona není vhodná k detekci částic, protože výsledné ionizační proudy jsou velmi
# malé a zároveň je jejich velikost citlivá na přiloženém napětí.
#
# Oblast nasyceného proudu, kde pracují ionizační komory, je k detekci částic mnohem
# výhodnější. V oblasti je ionizační proud procházející komorou nezávislý na velikosti
# přiloženého napětí a stejné částice s různými energiemi jsou dobře rozlišitelné. Nevýhodou
# ionizačních komor jsou stále ještě velmi malé ionizační proudy a z toho plynoucí nároky na
# následné elektronické zpracování, a sice značné lineární zesílení, nízká úroveň šumu a
# podobně.
#
# Za touto oblastí následuje oblast proporcionálních počítačů. Jejich velkou předností je tak
# zvané plynové zesílení, které dosahuje tří až pěti řádů. Tyto počítače využívají zvyšování
# počtu iontů v plynové náplni sekundární ionizací ve srážkách. Protože závislost velikosti
# ionizačního proudu na přiloženém napětí je v této oblasti značně strmá, potřebují
# proporcionální počítače pro svoji správnou činnost velmi dobře stabilizovaný zdroj napětí.
# Na horním okraji oblasti proporcionality, tak zvaná oblast omezené proporcionality, se
# charakteristiky komory pro různé druhy částic začínají přibližovat a tato část oblasti není
# prakticky využívána.
#
# Koncový bod oblasti proporcionality, kde charakteristiky komory pro různé druhy částic
# se sbíhají v jeden bod, je takzvaný Geigerův práh. Nad tímto prahem pracují Geigerovy-Müllerovy počítače. Jejich předností je vysoké plynové zesílení. Geigerovy-Müllerovy počítače
# však nerozliší ani energie ani druhy částic dopadajícího záření.
#
# ## Ionizační komora
#
# Nejvyužívanějšími komorami jsou statické nízkotlaké komory s konstantní ionizací [1]. Jsou
# to vlastně plynové (vzduchové) kondenzátory. Působením ionizačního záření se udržuje konstantní ionizační proud, kterým se komora vybíjí, a velikost ionizačního proudu se
# vhodným způsobem měří. Jen u velmi silných zářičů je možné měřit tento proud velmi
# citlivým galvanometrem. Většinou se užívá elektrometru, na němž se zjišťuje časová změna
# napětí.
#
# Při práci s ionizační komorou lze použít buď impulsní, nebo integrální zapojení. V prvním
# případě je snímán buď proudový, nebo výhodněji napěťový impuls z odporu vřazeného do
# napájecího obvodu komory, zesiluje se a registruje. Ionizační komora v integrálním zapojení funguje
# jako detektor dávky ionizujícího záření. V tomto případě je na kondenzátor představující
# ionizační komoru přiloženo napětí $U$ a je na něm náboj $Q = CU$, kde $C$ je konstantní kapacita
# kondenzátoru. Ionizující částice procházejí účinným objemem komory, zanechávají zde po
# sobě ionty, které jsou odneseny na elektrody, kde svůj náboj zneutralizují. Dochází tak
# k přenosu náboje mezi elektrodami kondenzátoru a kondenzátor se vybíjí. Protože kapacita
# kondenzátoru je při daném uspořádání konstantní, pokles napětí odpovídá dávce záření,
# kterou komora zaregistrovala. Časová změna napětí na kondenzátoru pak odpovídá intenzitě
# registrovaného záření.
#
# Vzduch v ionizační komoře není za obvyklých podmínek dokonalým izolátorem. Díky tomu
# a díky kosmickému záření či díky stopovým množstvím radioaktivních prvků, které jsou
# přítomny ve všech látkách, se komora vybíjí. I když je tento takzvaný svodový proud velmi
# malý, může být srovnatelný s ionizačním proudem. Měření vždy musí tento efekt vzít v úvahu.
#
# Ačkoli jsou ionizační komory principiálně stejné pro detekci různých druhů záření,
# konstrukčně se liší. Částice alfa pocházející z přirozeně radioaktivních vzorků mají ve vzduchu
# malý dolet. Například dolet nejenergičtějších alfa-částic, které vyletují z radioaktivního izotopu
# polonia $^{212}\mathrm{Po}$ a mají kinetickou energii $T_0 = 8.776~\mathrm{MeV}$, je ve vzduchu za normálních
# podmínek menší než $9~\mathrm{cm}$. Proto se zářiče alfa vkládají dovnitř do komory válcového tvaru o
# průměru asi $18~\mathrm{cm}$ tak, aby většina alfa-částic zanechala svou energii v komoře.
#
# Protože dolet beta-částic z přirozeně radioaktivních vzorků je ve vzduchu za normálních
# podmínek několik metrů, ionizační komory pro registraci záření beta se konstruují co největší. I
# tak se v účinném prostoru komory absorbuje jen část elektronů a toto zařízení se nejčastěji
# používá na srovnávací měření pro stejné druhy částic o stejné energii.
#
# Přímá ionizace vzduchu záření gamma je velmi malá. Proto je konstrukce ionizačních komor pro
# gamma-záření značně odlišná od předcházejících dvou zařízení. Zářič je umístěn vně komory a
# stěny komory pracují jako konvertor záření gamma na elektrony. Protože pravděpodobnost interakce
# gamma-záření s hmotou roste s protonovým číslem látky, používají se komory se silnými stěnami
# z olova, oceli nebo mosazi.
#
# # Experimentální uspořádání
#
# Předmětem studia jsou dva plynové detektory - desková ionizační komora (IK) s nastavitelnou vzdáleností
# elektrod a Geigerův-Müllerův (GM) detektor. Oba detektory se připojují ke stejnému konektoru. Funkce tohoto
# konektoru jsou však různé při připojení IK, nebo GM detektoru. Schéma konektoru je na
# obr. 2.
#
# Pro měření ionizačního proudu IK je používán pikoampérmetr KEITHLEY 6487. Tento
# přístroj má vestavěn zdroj napětí $0-500~\mathrm{V}$. Schéma zapojení viz obr.3. Napětí se
# nastavuje pomocí tlačítek na čelním panelu přístroje v oblasti V-SOURCE. Šipkami nahoru,
# dolů volíme hodnotu napětí. Stisknutím tlačítka OPER dojde k zapnutí nastaveného napětí,
# současně se rozsvítí kontrolka VOLTAGE SOURCE OPERATE. Opětovným stiskem tlačítka
# OPER se napětí vypne a kontrolka zhasne.
#
# Pro studium GM detektoru je používán zdroj vysokého napětí $0-2000~\mathrm{V}$ přístroje NEMEC. Při
# měření nepřekračujte napětí $1500~\mathrm{V}$, aby nedošlo k destrukci GM detektoru! Amplituda
# impulsů je měřena pomocí osciloskopu se vstupním odporem $1~\mathrm{M}\Omega$. Schéma zapojení viz
# obr.4.
#
# !['Schéma konektoru pro připojení plynového detektoru'](figures/konektor_cs.png)
#
# Obr. 2: Schéma konektoru pro připojení plynového detektoru
#
#
# !['Schéma zapojení pro měření s ionizační komorou'](figures/IK_cs.png)
#
# Obr. 3: Schéma zapojení pro měření s ionizační komorou
#
#
# !['Schéma zapojení pro měření s GM detektorem'](figures/GM_cs.png)
#
# Obr. 4: Schéma zapojení pro měření s GM detektorem

# %% [markdown]
# # V-A charakteristika ionizační komory

# %% [markdown]
# $\color{red}{\textbf{Úkol:}}$ Pomocí ionizační komory zjistěte, který zdroj alfa záření $^{239}\mathrm{Pu}$ má vyšší aktivitu: EA-13, nebo EA-14. Diskutujte svou strategii a výsledek.

# %% [markdown]
# $\color{red}{\textbf{Řešení:}}$

# %% [markdown]
# $\color{red}{\textbf{Úkol:}}$ Pomocí zdroje s vyšší aktivitou změřte V-A charakteristiku ionizační komory v rozsahu $0-500~\mathrm{V}$. Proveďte to pro dvě různé vzdálenosti elektrod; zvolte některé vhodné vzdálenosti. Měřte například v krocích 1-2 V do 20 V, pak po 10 V do 100 V nakonec po 100 V do 500 V.

# %%
# Solution.

# TODO: fill your measured data into the pandas DataFrame `df_measurements` below.
# TODO: fill in the distances in cm you chose. Set the variables `dist1` and `dist2`.
# TODO: fill the absolute uncertainties of the current measurements in pA into the dictionary `uncertainty` below.

import pandas as pd

# Chosen distances in cm.
dist1 =   # in cm
dist2 =   # in cm

# Create a DataFrame. The columns are:
#  - 'U' for voltage in V,
#  - 'I_dist1' for current in pA at distance dist1,
#  - 'I_dist2' for current in pA at distance dist2.
df_measurements = pd.DataFrame({
    'U'      : [],
    'I_dist1': [],
    'I_dist2': [],
})
display_names = {'U'       : 'U [V]',
                 'I_dist1' : f'I [pA] ({dist1} cm)',
                 'I_dist2' : f'I [pA] ({dist2} cm)',
                }

# Absolute uncertainty for all current measurements in pA.
# Values stored under the keys `dist1` and `dist2` correspond to the uncertainty
# for the current measurements at the respective distances.
# Each value is just one number, since the uncertainty is the same for all measurements
# at a given distance.
uncertainty = {dist1: , dist2: }

# Display the table
print(df_measurements.rename(columns = display_names).to_string(index = False))

# %% [markdown]
# $\color{red}{\textbf{Úkol:}}$ Vykreslete naměřené V-A charakteristiky.

# %%
# Solution.

import matplotlib.pyplot as plt

def plot_raw(x, y, y_unc, title, xlabel = 'U [V]', ylabel = 'I [pA]'):
    """
    Plot the measured data.
    """

    # Plot the data.
    plt.errorbar(x, y, y_unc, fmt='o', label='Data', color='black')

    # Labels etc.
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.legend(loc = 'lower right')
    plt.title(title)
    plt.show()

# Plot the data for the distance 1.
plot_raw(df_measurements['U'], df_measurements['I_dist1'], uncertainty[dist1], f'V-A Characteristics at {dist1} cm Distance')
# Plot the data for the distance 2.
plot_raw(df_measurements['U'], df_measurements['I_dist2'], uncertainty[dist2], f'V-A Characteristics at {dist2} cm Distance')

# %% [markdown]
# $\color{red}{\textbf{Úkol:}}$ Diskutujte, jaké oblasti vidíte ve vykreslených V-A závislostech.

# %% [markdown]
# $\color{red}{\textbf{Řešení:}}$

# %% [markdown]
# $\color{red}{\textbf{Úkol:}}$ Proložte každou oblast ve výše uvedených grafech lineární funkcí. Oblasti definujte zadáním čísel `N_reg1` a `N_reg2`, která mají význam prvních `N_reg1` a posledních `N_reg2` bodů z naměřené V-A charakteristiky. Toto proveďte pro obě vzdálenosti elektrod. Vykreslete výsledky.

# %%
# Solution.
#  - Fit the first `N_reg1` current-voltage values with a linear function.
#  - Fit the last `N_reg2` current-voltage values with a different linear function.
#  - Do this for both distances `dist1` and `dist2` and plot the results.

# TODO: define the two regions in the V-A characteristic by setting the numbers `N_reg1` and `N_reg2`.
# You might need to try this cell several times to find suitable values.
N_reg1 =     # Number of points in region 1 (the first N_reg1 points of the V-A characteristic)
N_reg2 =     # Number of points in region 2 (the last N_reg2 points of the V-A characteristic)


# Imports.
from scipy.optimize import curve_fit, OptimizeWarning
import warnings
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
import uncertainties

# Define the plotting function.
# Note that 'reg1' and 'reg2' refer to the first and second fitted regions, respectively.
def plot_fits(x, y, y_unc, a_reg1, b_reg1, N_reg1, a_reg2 = None, b_reg2 = None, N_reg2 = None, title = None):

    # Convert inputs to numpy arrays.
    x = np.array(x)
    y = np.array(y)
    y_unc = np.array(y_unc)

    # Plot the data.
    plt.errorbar(x, y, y_unc, fmt='o', label='Data', color='black')

    # Plot the region 1 fit function.
    plt.plot(x[:N_reg1], linear(x[:N_reg1], a_reg1, b_reg1), label='Fit reg. 1', color='red')

    # Plot the region 2 fit function.
    if a_reg2 and b_reg2 and N_reg2:
        plt.plot(x[-N_reg2:], linear(x[-N_reg2:], a_reg2, b_reg2), label='Fit reg. 2', color='blue')

    # get the current legend handles and labels
    handles, labels = plt.gca().get_legend_handles_labels()
    plt.legend(handles=handles[::-1], labels=labels[::-1])  # reverse the order

    # Labels etc.
    plt.xlabel('U [V]')
    plt.ylabel('I [pA]')
    if title:
        plt.title(title)
    plt.legend(loc = 'lower right')
    plt.show()

# Define the linear model.
def linear(x, a, b):
    return a * x + b

# Function implementing the fit procedure.
# Voltage and current are iterables containing the measured values.
# Uncertainty is an iterable containing the measurement uncertainties for each current value.
# Returns: the fit parameters a, b, taking into account their correlation
# thanks to the uncertainties package.
def fit(U, I, I_unc):

    # Fit the linear model to the data.
    try:
        with warnings.catch_warnings():
            warnings.simplefilter("error", OptimizeWarning)
            
            # The curve_fit call is inside the context and try block.
            nom_ab, cov_ab = curve_fit(linear, U, I, sigma = I_unc, absolute_sigma = True)

    except OptimizeWarning as e:
        print(f"Caught an OptimizeWarning message from scipy.optimize.curve_fit: {e}.")
        print(f"The number of points used for fitting was: {len(U)}.")
        return

    # Calculate the standard errors of the fitted parameters.
    a, b = uncertainties.correlated_values(nom_ab, cov_ab)

    # Return the fit results.
    return a, b


for distance in [dist1, dist2]:

    # Get the current and voltage values for the fit.
    if distance == dist1:
        I = df_measurements[f'I_dist1']
    elif distance == dist2:
        I = df_measurements[f'I_dist2']
    else:
        raise ValueError("Unknown distance of the electrodes!")
    U = df_measurements['U']

    # Get the uncertainty.
    I_unc = [uncertainty[distance] for _ in U]

    # Fit the low-voltage region, i.e. the first N_reg1 points.
    a_reg1, b_reg1 = fit(U[:N_reg1], I[:N_reg1], I_unc[:N_reg1])

    # Fit the high-voltage region, i.e. the last N_reg2 points.
    a_reg2, b_reg2 = fit(U[-N_reg2:], I[-N_reg2:], I_unc[-N_reg2:])

    # Print the results.
    print()
    print(f"Electrodes distance: {distance} cm")
    print("=========================")
    print()
    print("  Region 1:")
    print("  -----------")
    print(f"  N = {N_reg1}")
    print(f"  Fit parameters: a = {a_reg1:.4f}, b = {b_reg1:.4f}")
    print()
    print("  Region 2:")
    print("  -----------------")
    print(f"  N = {N_reg2}")
    print(f"  Fit parameters: a = {a_reg2:.4f}, b = {b_reg2:.4f}")
    print()

    # Plot the data and the fit.
    plot_fits(U, I, I_unc,
            a_reg1.nominal_value, b_reg1.nominal_value, N_reg1,
            a_reg2.nominal_value, b_reg2.nominal_value, N_reg2,
            title = f"Ionisation chamber, electrode distance: {distance} cm")
    
    # Caption for the figure.
    print(
      f"""
      Figure: Ionisation chamber current as a function of the applied voltage at an electrode distance of {distance} cm.
      Black points: measured data with error bars.
      Red solid line: linear fit for small voltages; blue solid line: linear fit for large voltages.
      """)
    
    # Plot just the low-voltage fit region.
    plot_fits(U[:N_reg1], I[:N_reg1], I_unc[:N_reg1],
            a_reg1.nominal_value, b_reg1.nominal_value, N_reg1,
            title = f"Ionisation chamber, electrode distance: {distance} cm (low-voltage part)")
    
    # Caption for the figure.
    print(
      f"""
      Figure: Ionisation chamber current as a function of the applied voltage at an electrode distance of {distance} cm.
      Just the low-voltage part is shown.
      Black points: measured data with error bars.
      Red solid line: linear fit for small voltages.
      """)

# %% [markdown]
# $\color{red}{\textbf{Úkol:}}$ Diskutujte obdržené výsledky. Určete optimální napětí a optimální vzdálenost mezi elektrodami ionizační komory.

# %% [markdown]
# # Měření ionizačního proudu při různých vzdálenostech elektrod

# %% [markdown]
# $\color{red}{\textbf{Úkol:}}$ Vypočítejte očekávaný dosah $R$ alfa částic ze zdroje $^{239}\mathrm{Pu}$. Použijte následující fakta:
#
# - Nejvyšší energie emitovaných alfa částic je $5156.59 \pm 0.14~\mathrm{keV}$.
#
# - Střední energie pro vytvoření iontového páru ve vzduchu je přibližně $35~\mathrm{eV}$.
#
# - Dosah $R$ alfa částic ve vzduchu lze aproximovat pomocí vzorce: $R = \xi \cdot E_{\alpha}^{3/2}$, kde $\xi = 0.31~\mathrm{cm} \cdot \mathrm{MeV}^{-3/2}$ je konstanta a $E_{\alpha}$ je energie alfa částice.

# %%
# Solution.

# TODO: perform the calculation.

# %% [markdown]
# $\color{red}{\textbf{Úkol:}}$ Pomocí zdroje $^{239}\mathrm{Pu}$ s vyšší aktivitou změřte ionizační proud pro šest různých vzdáleností elektrod: 1 cm, 2 cm, 3 cm, 4 cm, 5 cm a 6 cm. Použijte vhodné napětí určené pomocí měření V-A charakteristik.

# %%
# Solution.

# TODO: fill your measured data into the pandas DataFrame below.

import pandas as pd

# Create a DataFrame. The columns are:
#  - 'Distance [cm]' for the distance in cm,
#  - 'I [pA]' for the current in pA,
#  - 'I_unc [pA]' for the uncertainty of the current in pA.
df_ic = pd.DataFrame({
    'Distance [cm]': [],
    'I [pA]'       : [],
    'I_unc [pA]'   : [],
})

# Display the table
print(df_ic.to_string(index=False))

# %% [markdown]
# $\color{red}{\textbf{Úkol:}}$ Vykreslete naměřený ionizační proud jako funkci vzdálenosti elektrod.

# %%
# Solution.

# Use the plot_raw function defined above.
plot_raw(df_ic['Distance [cm]'], df_ic['I [pA]'], df_ic['I_unc [pA]'], 'Ionisation Chamber Current vs. Electrode Distance', xlabel = 'd [cm]')

# %% [markdown]
# $\color{red}{\textbf{Úkol:}}$ Diskutujte, jaké trendy vidíte ve vykresleném grafu.

# %% [markdown]
# $\color{red}{\textbf{Řešení:}}$

# %% [markdown]
# $\color{red}{\textbf{Úkol:}}$ Odhadněte dosah alfa částic ze zdroje $^{239}\mathrm{Pu}$ pomocí naměřených ionizačních proudů. Odhad může být průsečík dvou lineárních funkcí proložených datovými body proud vs. vzdálenost. Prvních N bodů (vzdálenosti 1 cm, 2 cm, ...) a posledních M bodů (vzdálenosti ..., 5 cm, 6 cm) prokládejte samostatně. Na základě očekávaného dosahu a výše uvedeného grafu zvolte prahovou vzdálenost X [cm], která rozdělí dvě oblasti s N a M body.

# %%
# Solution.

# TODO: set the threshold distance X [cm] splitting the two regions with N and M points.
# Note that e.g X = 3.0 would split the points into (1, 2) and (3, 4, 5, 6).
X = 

# Get the points corresponding to the lower distances from the dataframe.
d_small = df_ic[df_ic['Distance [cm]'] < X]['Distance [cm]']
I_small = df_ic[df_ic['Distance [cm]'] < X]['I [pA]']
I_unc_small = df_ic[df_ic['Distance [cm]'] < X]['I_unc [pA]']

# Perform the linear fit to the small-distance data points.
a_small, b_small = fit(d_small, I_small, I_unc_small)
print(f"Fit for small distances {tuple(d_small)}: a={a_small}, b={b_small}")

# Get the points corresponding to the larger distances from the dataframe.
d_large = df_ic[df_ic['Distance [cm]'] >= X]['Distance [cm]']
I_large = df_ic[df_ic['Distance [cm]'] >= X]['I [pA]']
I_unc_large = df_ic[df_ic['Distance [cm]'] >= X]['I_unc [pA]']

# Calculate the constant fit from the large-distance data points.
weights = 1 / (I_unc_large ** 2)
I_const = np.average(I_large, weights=weights)
I_const_unc = np.sqrt(1 / np.sum(weights))
print(f"Constant fit for large distances {tuple(d_large)}: I = {I_const:.3f} ± {I_const_unc:.3f} pA")

# Calculate the intersection point.
x_intersect = (I_const - b_small) / a_small
y_intersect = I_const

# Print the intersection point.
print(f"Intersection point: ({x_intersect:.2f} cm, {y_intersect:.2f} pA)")

# Warn if intersection doesn't coincide with user-defined X (more than 10% relative difference)
if abs(x_intersect.nominal_value - X) / X > 0.1:
    print(f"⚠️  Warning: intersection (x = {x_intersect.nominal_value:.2f} cm) "
          f"significantly differs from user-defined X = {X:.2f} cm")

# Plot the results.
# =================

# --- Plot data points ---
plt.errorbar(
    np.concatenate((d_small, d_large)),
    np.concatenate((I_small, I_large)),
    np.concatenate((I_unc_small, I_unc_large)),
    fmt='o', color='black', label='Data'
)

# --- Solid "final" fits only over fitted intervals ---
# Linear (red) on actual small-distance range
d_space_small_fit = np.linspace(d_small.min(), d_small.max(), 100)
plt.plot(
    d_space_small_fit,
    linear(d_space_small_fit, a_small.nominal_value, b_small.nominal_value),
    color='red', lw=2, label=f'Lin., d < {X:.1f} cm'
)

# Constant (blue) on actual large-distance range
plt.hlines(
    I_const,
    d_large.min(),
    d_large.max(),
    color='blue', lw=2, label=f'Const., d ≥ {X:.1f} cm'
)

# --- Dashed raw extrapolations for comparison ---
d_space_full = np.linspace(d_small.min(), d_large.max(), 200)
plt.plot(
    d_space_full,
    linear(d_space_full, a_small.nominal_value, b_small.nominal_value),
    color='red', linestyle='--', alpha=0.4, label='Lin.'
)
plt.hlines(
    I_const,
    d_small.min(),
    d_large.max(),
    color='blue', linestyle='--', alpha=0.4, label='Const.'
)

# --- Intersection marker ---
plt.axvline(x=x_intersect.nominal_value, linestyle='--', color='gray', label=r'$R$')

# --- Legend, labels, title ---
handles, labels = plt.gca().get_legend_handles_labels()
plt.legend(handles=handles[::-1], labels=labels[::-1])
plt.xlabel('d [cm]')
plt.ylabel('I [pA]')
plt.title("Ionisation current as a function of the electrode distance")
plt.show()

# Print figure caption.
print(
  """
  Figure: Ionisation current as a function of the electrode distance.
  Red solid line: linear fit for small distances; blue solid line: constant fit for large distances.
  Dashed lines: extrapolations of the fits. Gray dashed line: intersection point R.
  """)

# %% [markdown]
# $\color{red}{\textbf{Úkol:}}$ Diskutujte volbu prahové vzdálenosti X. Porovnejte naměřený dosah s očekávaným.

# %% [markdown]
# $\color{red}{\textbf{Řešení:}}$

# %% [markdown]
# $\color{red}{\textbf{Úkol:}}$ Vysvětlete, proč je použitý odhad dosahu alfa částic (průsečík dvou proložených funkcí) hrubý, ale přesto celkem rozumný. Vysvětlete, proč je rozumné očekávat, že funkce budou lineární a konstantní (hint: vzpomeňte si na Braggovu křivku).

# %% [markdown]
# $\color{red}{\textbf{Řešení:}}$

# %% [markdown]
# # Svodový proud

# %% [markdown]
# $\color{red}{\textbf{Úkol:}}$ Změřte svodový proud v ionizační komoře jako funkci přiloženého napětí v rozsahu $0-500~\mathrm{V}$. Použijte optimální vzdálenost elektrod určenou v předchozím úkolu.

# %%
# Solution.

# TODO: fill your measured data into the pandas DataFrame below.

# Create DataFrame containing the measured data. The columns are:
#  - 'U [V]' for the voltage in V,
#  - 'I [pA]' for the leakage current in pA,
#  - 'I_unc [pA]' for the uncertainty of the leakage current in pA.
df_leakage = pd.DataFrame({
    'U [V]'     : [],
    'I [pA]'    : [],
    'I_unc [pA]': [],
})

# Display the table.
print(df_leakage.to_string(index=False))

# %% [markdown]
# $\color{red}{\textbf{Úkol:}}$ Diskutujte, zda je nutné korigovat všechny naměřené hodnoty ionizačního proudu o svodový proud.

# %% [markdown]
# $\color{red}{\textbf{Řešení:}}$

# %% [markdown]
# # Aktivita radioaktivních zdrojů
#
# K dispozici jsou dva zdroje alfa záření $^{239}\mathrm{Pu}$: EA-13 a EA-14.
# Jejich aktivita byla změřena 1. 12. 2020 a je uvedena v následující tabulce spolu se skutečnou aktivitou, vyhodnocenou pomocí rozpadového zákona
#
# $A(t) = A_0 e^{-t/T \ln(2)}$,
#
# kde $T = 24110 \text{ let}$ je poločas rozpadu a $t$ je čas uplynulý od referenčního data.

# %% [markdown]
# $\color{red}{\textbf{Úkol:}}$ Nastavte aktuální rok v kódu níže.

# %%
# TODO: set the variable `year` to the current year.

# The current year.
year = 

import numpy as np
import pandas as pd

# The reference activities of the 239Pu sources.
a13_ref = 99.50
a14_ref = 1485.00

# Calculate the current activity of the radioactive 239Pu source,
# given its reference activity and the time elapsed since the reference date.
def current_activity(a_ref, year):
    T = 24110
    t = year - 2020
    return a_ref * np.exp(-t / T * np.log(2))

# Print a table summarizing the values.
# Create a pandas dataframe for this purpose.
data = {
    "Source": ["EA-13", "EA-14"],
    "A_ref [1/s]": [a13_ref, a14_ref],
    "A_act [1/s]": [current_activity(a13_ref, year), current_activity(a14_ref, year)]
}
df_act = pd.DataFrame(data)
print(df_act.to_string(index=False))
print()

# Print the activity ratio.
print(f"Activity ratio A(EA-14)/A(EA-13): {a14_ref/a13_ref:.2f}")

# %% [markdown]
# $\color{red}{\textbf{Úkol:}}$ Změřte aktivitu dvou zdrojů $^{239}\mathrm{Pu}$ pomocí ionizační komory. Použijte vztah $A = 2 I E_i / (e E_k)$, kde:
#
# - $A$ je aktivita,
#
# - $I$ je ionizační proud,
#
# - $E_i \approx 35 \ \text{eV}$ je energie pro vytvoření iontového páru ve vzduchu,
#
# - $e = 1.602 \times 10^{-19} \ C$ je elementární náboj,
#
# - $E_k$ je kinetická energie emitovaných alfa částic. Nezapomeňte, že alfa částice z $^{239}\mathrm{Pu}$ mají několik různých energií.
#
# - Geometrický faktor 2 plyne z úvahy, že ionizovat mohou pouze alfa částice letící do horní poloviny prostorového úhlu.

# %%
# Solution.

# TODO: fill the measured values of the ionization currents in pA into the array `ionization_currents` below.
# TODO: fill in the absolute uncertainties of the current measurements in pA into the array `ionization_currents_unc` below.

# Ionization current measurements in pA.
ionization_currents     = []
ionization_currents_unc = []

from uncertainties import unumpy

# Calculate the average alpha particle energy, first.
# Create a DataFrame with the alpha particle energies and their intensities
df_alpha = pd.DataFrame({
    'Energy [keV]': [5111.2, 5105.5, 5144.3, 5156.59],
    'Energy_unc [keV]': [0.2, 0.8, 0.8, 0.14],
    'Intensity [%]': [0.03, 11.5, 15.1, 73.3],
    'Intensity_unc [%]': [0.03, 0.8, 0.8, 0.8]
})

# Print the DataFrame
print("Alpha particle energies and their intensities")
print('---------------------------------------------')
print(df_alpha.to_string(index=False))
print()

# Create arrays of nominal values and uncertainties
energies = unumpy.uarray(df_alpha['Energy [keV]'].values, df_alpha['Energy_unc [keV]'].values)
intensities = unumpy.uarray(df_alpha['Intensity [%]'].values, df_alpha['Intensity_unc [%]'].values)

# Calculate weighted average with proper uncertainty propagation
weighted_energy = np.sum(energies * intensities) / np.sum(intensities)
print("Weighted average alpha particle energy:", f"{weighted_energy:.2f} keV")
print()

# Evaluate the activities of the sources, given the ionization current measurements
ionization_currents = unumpy.uarray(ionization_currents, ionization_currents_unc) * 1.e-12  # Convert pA to A
activities = ionization_currents * 2 * 35 / (1.602e-19 * weighted_energy * 1e3)  # Convert keV to eV

# Create a DataFrame to display the activities and uncertainties nicely
df_activities = pd.DataFrame({
    'Source': ['EA-13', 'EA-14'],
    'Measured Activity [1/s]': [
        f"{activities[0].nominal_value:.1f} ± {activities[0].std_dev:.1f}",
        f"{activities[1].nominal_value:.1f} ± {activities[1].std_dev:.1f}"
    ],
    'Reference Activity [1/s]': [a13_ref, a14_ref]
})

print("Measured activities of the sources")
print('----------------------------------')
print(df_activities.to_string(index=False))
print()

# Ratio of the activities
print("Measured activity ratio A(EA-14)/A(EA-13):", f"{activities[1] / activities[0]:.1f}")
print(f"Reference activity ratio A(EA-14)/A(EA-13): {a14_ref/a13_ref:.2f}")

# %% [markdown]
# $\color{red}{\textbf{Úkol:}}$ Porovnejte naměřenou aktivitu obou zdrojů s očekávanými hodnotami a diskutujte případné nesrovnalosti. Proveďte totéž pro naměřené a očekávané hodnoty poměru aktivit. Stručně vysvětlete rozdíl mezi absolutním a relativním měřením aktivit.

# %% [markdown]
# $\color{red}{\textbf{Řešení:}}$

# %% [markdown]
# # V-A charakteristika Geigerova-Müllerova detektoru

# %% [markdown]
# $\color{red}{\textbf{Úkol:}}$ Změřte V-A charakteristiku Geigerova-Müllerova detektoru. Vytvořte tabulku napětí na GM detektoru, napětí na osciloskopu i s jeho neurčitostí a odpovídajícího proudu s neurčitostí. Zjistěte si, jaký je vstupní odpor osciloskopu!

# %%
# Solution.

# TODO: fill the oscilloscope resistance value into the variable `R_osc`.
R_osc =   # Resistance in ohms

# TODO: fill your measured data into the pandas DataFrame below.
# Don't forget to include both the GM detector voltage and the oscilloscope voltage.

# Create DataFrame containing the measured data. The columns are:
#  - 'U [kV]' for the voltage in kV,
#  - 'U_osc [mV]' for the oscilloscope voltage in mV,
#  - 'U_osc_unc [mV]' for the uncertainty of the oscilloscope voltage in mV.
df_gm = pd.DataFrame({
    'U [kV]'        : [],
    'U_osc [mV]'    : [],
    'U_osc_unc [mV]': [],
})

# Add two new columns:
#  - `I [pA]` calculated from `U_osc [mV]`.
#  - `I_unc [pA]` calculated from `U_osc_unc [mV]`.
df_gm['I [pA]']     = df_gm['U_osc [mV]']     * 1e-3 / R_osc * 1e12
df_gm['I_unc [pA]'] = df_gm['U_osc_unc [mV]'] * 1e-3 / R_osc * 1e12

# Display the DataFrame
print(df_gm.to_string(index=False))

# %% [markdown]
# $\color{red}{\textbf{Úkol:}}$ Proložte exponenciální model naměřenými daty a vykreslete jej. Zvolte vhodnou škálu osy $y$ (lineární, nebo logaritmickou).

# %%
# Solution.

# TODO: choose the appropriate scale (linear or logarithmic) for the y-axis of the plot.
# 'lin' = linear, 'log' = logarithmic
y_axis_scale = 

import numpy as np
import matplotlib.pyplot as plt

# Define the exponential model function.
def exponential_model(x, a, b, c):
    return a * np.exp(b * x) + c

# Remove all points where current is zero.
df_gm_nonzero = df_gm[df_gm['I [pA]'] > 0]

# Get the voltage and current values from df_gm.
U = df_gm_nonzero['U [kV]']
I = df_gm_nonzero['I [pA]']
I_unc = df_gm_nonzero['I_unc [pA]']

# Perform the fit.
pars, cov = curve_fit(exponential_model, U, I, sigma=I_unc, absolute_sigma=True)

# Print the fit parameters and their uncertainties.
for param, value, uncertainty in zip(['a', 'b', 'c'], pars, np.sqrt(np.diag(cov))):
    print(f"Parameter {param}: {value} +/- {uncertainty}")

# Plot the data and the model.
# ============================

# Create a range of x values for the model.
x_model = np.linspace(U.iloc[0], U.iloc[-1], 100)

# Calculate the corresponding y values using the fitted parameters.
y_model = exponential_model(x_model, *pars)

# Create the plot.
plt.errorbar(U, I, yerr=I_unc, fmt='o', label='Data', color='black')
plt.plot(x_model, y_model, label='Fit', color='red')

# Get the current legend handles and labels.
handles, labels = plt.gca().get_legend_handles_labels()
plt.legend(handles=handles[::-1], labels=labels[::-1])  # reverse the order

# Axes, labels...
plt.xlabel('U [kV]')
plt.ylabel('I [pA]')
if y_axis_scale == 'log':
    plt.yscale('log')
plt.title("V-A characteristic of the Geiger-Müller detector")
plt.show()

# %% [markdown]
# $\color{red}{\textbf{Úkol:}}$ Diskutujte V-A charakteristiku Geigerova-Müllerova detektoru a nafitovaný exponenciální model. Identifikujte charakteristické oblasti V-A charakteristiky GM detektoru.

# %% [markdown]
# $\color{red}{\textbf{Řešení:}}$

# %% [markdown]
# $\color{red}{\textbf{Úkol:}}$ Napište závěr.

# %% [markdown]
# $\color{red}{\textbf{Řešení:}}$
#
# # Závěr

# %% [markdown]
# # Literatura
#
# [1] W.R.Leo, Techniques for Nuclear and Particle Physics Experiments, Springer Verlag BerlinHeidelberg 1987
#
# [2] https://en.wikibooks.org/wiki/Basic_Physics_of_Nuclear_Medicine/Gas-Filled_Radiation_Detectors
